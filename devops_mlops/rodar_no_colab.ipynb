# %%
# !pip install -r requirements.txt

# %%
import yaml

config = {
    'path': '/content/data/processed', # Caminho que o Colab vai usar internamente
    'train': 'train/images',
    'val': 'test/images',
    'names': {0: 'AirPlane', 1: 'Bird', 2: 'Drone', 3: 'Helicopter'}
}

with open('configs/dataset.yaml', 'w') as f:
    yaml.dump(config, f)

# %%
# !python app/data_pipeline.py

# %%
# !python train.py
